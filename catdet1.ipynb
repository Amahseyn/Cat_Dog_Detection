# %%
import os
import numpy as np
import librosa
from skimage.transform import resize
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Input,MaxPool2D,Conv2D
from tensorflow.keras.applications import VGG16
from sklearn.model_selection import train_test_split
import tensorflow as tf
from random import sample

def time_stretch(audio, rate=1.1):
    return librosa.effects.time_stretch(y=audio, rate=rate)

def pitch_shift(audio, sr, n_steps=2):
    return librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=n_steps)

def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    augmented_audio = audio + noise_factor * noise
    return augmented_audio

def normalize(feature):
    return (feature - np.mean(feature)) / np.std(feature)

def load_data(main_directory,files,augment=False,size = 64):
    data = []
    labels = []

    for i,folder in sorted(enumerate(os.listdir(main_directory))):
        folder_path = os.path.join(main_directory, folder)
        if os.path.isdir(folder_path):


            for file in os.listdir(folder_path):
                if file.endswith(".wav") and file in files:
                    file_path = os.path.join(folder_path, file)
                    audio, sr = librosa.load(file_path, sr=None)

                    if augment:
                        augmentation_choice = np.random.random()
                        if augmentation_choice > 0.5:
                            audio = time_stretch(audio, rate=np.random.uniform(0.8, 1.2))
                        #augmentation_choice = np.random.random()
                        # if augmentation_choice > 0.5:
                        #     audio = pitch_shift(audio, sr, n_steps=np.random.randint(-3, 3))
                        augmentation_choice = np.random.random()
                        if augmentation_choice > 0.5:
                            audio = add_noise(audio, noise_factor=np.random.uniform(0.001, 0.01))

                    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
                    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=128)
                    spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr)

                    # mfccs = normalize(mfccs)
                    # mel_spectrogram = normalize(mel_spectrogram)
                    # spectral_contrast = normalize(spectral_contrast)

                    mfccs = resize(np.expand_dims(mfccs, axis=-1), (size, size))
                    mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), (size, size))
                    spectral_contrast = resize(np.expand_dims(spectral_contrast, axis=-1), (size, size))

                    combined_features = np.concatenate([mel_spectrogram,mfccs,spectral_contrast], axis=-1)

                    data.append(combined_features)
                    labels.append(i)

    return np.array(data), np.array(labels)


main_directory = "/content/drive/MyDrive/Cat_Dog_Detection/mydata"
files = os.listdir("/content/drive/MyDrive/Cat_Dog_Detection/mydata/cat")
files =[f for f in files if "cat" not in f]
files.extend(sample(os.listdir("/content/drive/MyDrive/Cat_Dog_Detection/mydata/other"),60))
train_sample,test_sample= train_test_split(files, test_size=0.2)
train_sample,val_sample= train_test_split(train_sample, test_size=0.25)
print(len(train_sample),len(test_sample),len(val_sample))
x_train,y_train = load_data(main_directory,train_sample,augment=True)
x_val,y_val = load_data(main_directory,val_sample,augment=False)
x_test,y_test = load_data(main_directory,test_sample,augment=False)
print(len(x_train),len(x_val),len(x_test))

y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

input_shape = x_train[0].shape
input_layer = Input(shape=input_shape)
x = Conv2D (filters =16, kernel_size =3, padding ='same', activation='relu')(input_layer)
x = BatchNormalization()(x)
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(x)
x = BatchNormalization()(x)

# x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# # 3rd Conv block

# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# #4th Conv block

# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# # 5th Conv block

# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# #Fully connected layers

x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(units = 32, activation ='relu')(x)
# x = Dense(units = 256, activation ='relu')(x)
output = Dense(units = 2, activation ='softmax')(x)
model = Model (inputs=input_layer, outputs =output)



model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=250, batch_size=16, validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 60 20 20
# 60 20 20
# Epoch 1/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 414ms/step - accuracy: 0.5433 - loss: 6.0391 - val_accuracy: 0.2500 - val_loss: 310.9434
# Epoch 2/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.8438 - loss: 2.9128 - val_accuracy: 0.2500 - val_loss: 320.4519
# Epoch 3/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.9762 - loss: 0.3350 - val_accuracy: 0.2500 - val_loss: 252.2988
# Epoch 4/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9829 - loss: 0.0817 - val_accuracy: 0.2500 - val_loss: 202.5803
# Epoch 5/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 1.0000 - loss: 6.6589e-04 - val_accuracy: 0.3000 - val_loss: 168.0683
# Epoch 6/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.3000 - val_loss: 142.2436
# Epoch 7/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.3500 - val_loss: 121.7769
# Epoch 8/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 5.2077e-05 - val_accuracy: 0.4000 - val_loss: 106.7472
# Epoch 9/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 1.0000 - loss: 5.1530e-05 - val_accuracy: 0.6500 - val_loss: 96.9899
# Epoch 10/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 1.0000 - loss: 7.7394e-04 - val_accuracy: 0.6500 - val_loss: 89.6937
# Epoch 11/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 1.0000 - loss: 8.0582e-05 - val_accuracy: 0.7000 - val_loss: 83.2053
# Epoch 12/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 1.0000 - loss: 6.6473e-04 - val_accuracy: 0.7000 - val_loss: 77.8545
# Epoch 13/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 1.0000 - loss: 4.1736e-05 - val_accuracy: 0.7000 - val_loss: 73.6540
# Epoch 14/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 1.0000 - loss: 1.2924e-05 - val_accuracy: 0.8000 - val_loss: 70.0854
# Epoch 15/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 1.3157e-05 - val_accuracy: 0.8000 - val_loss: 67.1753
# Epoch 16/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy:
250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 3.9046e-07 - val_accuracy: 0.8000 - val_loss: 39.1052
# Epoch 125/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - accuracy: 1.0000 - loss: 4.0730e-09 - val_accuracy: 0.8000 - val_loss: 39.0501
# Epoch 126/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 1.0000 - loss: 8.4539e-08 - val_accuracy: 0.8000 - val_loss: 39.1000
# Epoch 127/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 2.0365e-09 - val_accuracy: 0.8000 - val_loss: 39.1386
# Epoch 128/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 1.7037e-08 - val_accuracy: 0.8000 - val_loss: 39.1354
# Epoch 129/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 2.6474e-08 - val_accuracy: 0.8000 - val_loss: 39.1517
# Epoch 130/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 2.0365e-09 - val_accuracy: 0.8000 - val_loss: 39.1835
# Epoch 131/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1255
# Epoch 132/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0793
# Epoch 133/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 3.1455e-06 - val_accuracy: 0.8000 - val_loss: 39.1042
# Epoch 134/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 1.0000 - loss: 2.8511e-08 - val_accuracy: 0.8000 - val_loss: 39.0391
# Epoch 135/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0577
# Epoch 136/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 401ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0622
# Epoch 137/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0674
# Epoch 138/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 1.5606e-07 - val_accuracy: 0.8000 - val_loss: 39.0880
# Epoch 139/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0762
# Epoch 140/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1015
# Epoch 141/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 4.2836e-07 - val_accuracy: 0.8000 - val_loss: 39.1744
# Epoch 142/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 1.2914e-09 - val_accuracy: 0.8000 - val_loss: 39.1933
# Epoch 143/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 1.7692e-05 - val_accuracy: 0.8000 - val_loss: 39.1484
# Epoch 144/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 1.0000 - loss: 4.0730e-09 - val_accuracy: 0.8000 - val_loss: 39.1762
# Epoch 145/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 2.0365e-08 - val_accuracy: 0.8000 - val_loss: 39.1937
# Epoch 146/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - accuracy: 1.0000 - loss: 2.9832e-07 - val_accuracy: 0.8000 - val_loss: 39.2280
# Epoch 147/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - accuracy: 1.0000 - loss: 2.8876e-06 - val_accuracy: 0.8000 - val_loss: 39.2308
# Epoch 148/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2642
# Epoch 149/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 1.0000 - loss: 5.4577e-07 - val_accuracy: 0.8000 - val_loss: 39.3032
# Epoch 150/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3080
# Epoch 151/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 1.0000 - loss: 3.0994e-08 - val_accuracy: 0.8000 - val_loss: 39.3108
# Epoch 152/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 1.2010e-07 - val_accuracy: 0.8000 - val_loss: 39.3402
# Epoch 153/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3407
# Epoch 154/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 9.0400e-09 - val_accuracy: 0.8000 - val_loss: 39.3530
# Epoch 155/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 4.7286e-08 - val_accuracy: 0.8000 - val_loss: 39.2980
# Epoch 156/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3316
# Epoch 157/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2523
# Epoch 158/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 1.0000 - loss: 3.1739e-08 - val_accuracy: 0.8000 - val_loss: 39.2785
# Epoch 159/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - accuracy: 1.0000 - loss: 2.5829e-09 - val_accuracy: 0.8000 - val_loss: 39.2189
# Epoch 160/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - accuracy: 1.0000 - loss: 7.9473e-10 - val_accuracy: 0.8000 - val_loss: 39.2459
# Epoch 161/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 1.0000 - loss: 2.9271e-07 - val_accuracy: 0.8000 - val_loss: 39.2800
# Epoch 162/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2703
# Epoch 163/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 3.3577e-08 - val_accuracy: 0.8000 - val_loss: 39.2952
# Epoch 164/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3144
# Epoch 165/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3411
# Epoch 166/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3629
# Epoch 167/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 5.2452e-08 - val_accuracy: 0.8000 - val_loss: 39.3059
# Epoch 168/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3070
# Epoch 169/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 3.5266e-09 - val_accuracy: 0.8000 - val_loss: 39.2982
# Epoch 170/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2511
# Epoch 171/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2012
# Epoch 172/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 1.0000 - loss: 2.0365e-09 - val_accuracy: 0.8000 - val_loss: 39.2128
# Epoch 173/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1763
# Epoch 174/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 3.8743e-09 - val_accuracy: 0.8000 - val_loss: 39.1993
# Epoch 175/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 7.0532e-09 - val_accuracy: 0.8000 - val_loss: 39.1962
# Epoch 176/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 6.1075e-06 - val_accuracy: 0.8000 - val_loss: 39.1720
# Epoch 177/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1519
# Epoch 178/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 1.0000 - loss: 1.5895e-09 - val_accuracy: 0.8000 - val_loss: 39.1633
# Epoch 179/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 1.0000 - loss: 1.8598e-06 - val_accuracy: 0.8000 - val_loss: 39.2207
# Epoch 180/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1583
# Epoch 181/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1785
# Epoch 182/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1689
# Epoch 183/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1864
# Epoch 184/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 4.1525e-08 - val_accuracy: 0.8000 - val_loss: 39.1324
# Epoch 185/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0526
# Epoch 186/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.0754
# Epoch 187/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 3.9367e-05 - val_accuracy: 0.8000 - val_loss: 39.1069
# Epoch 188/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1563
# Epoch 189/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1524
# Epoch 190/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1974
# Epoch 191/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1738
# Epoch 192/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 2.0365e-09 - val_accuracy: 0.8000 - val_loss: 39.1911
# Epoch 193/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 4.0730e-09 - val_accuracy: 0.8000 - val_loss: 39.2090
# Epoch 194/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 1.0000 - loss: 3.1739e-08 - val_accuracy: 0.8000 - val_loss: 39.1887
# Epoch 195/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2468
# Epoch 196/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2515
# Epoch 197/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2568
# Epoch 198/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 3.9736e-09 - val_accuracy: 0.8000 - val_loss: 39.2502
# Epoch 199/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 2.5928e-08 - val_accuracy: 0.8000 - val_loss: 39.2749
# Epoch 200/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 4.6194e-09 - val_accuracy: 0.8000 - val_loss: 39.3170
# Epoch 201/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2562
# Epoch 202/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 8.4637e-07 - val_accuracy: 0.8000 - val_loss: 39.2433
# Epoch 203/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 5.4924e-05 - val_accuracy: 0.8000 - val_loss: 39.2660
# Epoch 204/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - accuracy: 1.0000 - loss: 7.0532e-09 - val_accuracy: 0.8000 - val_loss: 39.2995
# Epoch 205/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - accuracy: 1.0000 - loss: 3.5573e-06 - val_accuracy: 0.8000 - val_loss: 39.3203
# Epoch 206/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 1.0000 - loss: 3.6930e-07 - val_accuracy: 0.8000 - val_loss: 39.3488
# Epoch 207/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 1.0000 - loss: 9.9838e-09 - val_accuracy: 0.8000 - val_loss: 39.3361
# Epoch 208/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 1.7668e-06 - val_accuracy: 0.8000 - val_loss: 39.2888
# Epoch 209/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 1.6272e-07 - val_accuracy: 0.8000 - val_loss: 39.2533
# Epoch 210/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2798
# Epoch 211/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 2.5829e-09 - val_accuracy: 0.8000 - val_loss: 39.2805
# Epoch 212/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2929
# Epoch 213/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2846
# Epoch 214/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3038
# Epoch 215/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2996
# Epoch 216/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 1.0000 - loss: 6.3578e-09 - val_accuracy: 0.8000 - val_loss: 39.2947
# Epoch 217/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3206
# Epoch 218/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.3315
# Epoch 219/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2790
# Epoch 220/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2898
# Epoch 221/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 1.0580e-08 - val_accuracy: 0.8000 - val_loss: 39.2877
# Epoch 222/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.2996
# Epoch 223/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 2.1060e-08 - val_accuracy: 0.8000 - val_loss: 39.3181
# Epoch 224/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 4.3352e-07 - val_accuracy: 0.8000 - val_loss: 39.2564
# Epoch 225/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 1.2914e-09 - val_accuracy: 0.8000 - val_loss: 39.1737
# Epoch 226/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 39.1532
# Epoch 227/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 9.2685e-06 - val_accuracy: 0.8000 - val_loss: 39.6758
# Epoch 228/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 1.0000 - loss: 6.3578e-09 - val_accuracy: 0.8000 - val_loss: 40.5630
# Epoch 229/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - accuracy: 1.0000 - loss: 2.3246e-08 - val_accuracy: 0.8000 - val_loss: 41.1376
# Epoch 230/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 41.5425
# Epoch 231/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 41.8137
# Epoch 232/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 1.0000 - loss: 5.0486e-06 - val_accuracy: 0.8000 - val_loss: 41.9652
# Epoch 233/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.1409
# Epoch 234/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 3.3279e-09 - val_accuracy: 0.8000 - val_loss: 42.2018
# Epoch 235/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 1.0000 - loss: 9.9814e-05 - val_accuracy: 0.8000 - val_loss: 42.2530
# Epoch 236/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 2.1954e-08 - val_accuracy: 0.8000 - val_loss: 42.3310
# Epoch 237/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.3687
# Epoch 238/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.3174
# Epoch 239/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 1.6292e-08 - val_accuracy: 0.8000 - val_loss: 42.3471
# Epoch 240/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.3472
# Epoch 241/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 1.0000 - loss: 7.7486e-09 - val_accuracy: 0.8000 - val_loss: 42.3845
# Epoch 242/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 2.1160e-08 - val_accuracy: 0.8000 - val_loss: 42.3988
# Epoch 243/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.3232
# Epoch 244/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 1.0000 - loss: 2.3469e-06 - val_accuracy: 0.8000 - val_loss: 42.3186
# Epoch 245/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.2576
# Epoch 246/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.2594
# Epoch 247/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 1.0000 - loss: 2.0365e-09 - val_accuracy: 0.8000 - val_loss: 42.2987
# Epoch 248/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 8.7420e-09 - val_accuracy: 0.8000 - val_loss: 42.2346
# Epoch 249/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.1843
# Epoch 250/250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 42.2093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9000 - loss: 1.7329
# Test accuracy: 0.9000
