# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/Amahseyn/Cat_Dog_Detection
# Out:
# Cloning into 'Cat_Dog_Detection'...
# remote: Enumerating objects: 834, done.
# remote: Counting objects: 100% (640/640), done.
# remote: Compressing objects: 100% (633/633), done.
# remote: Total 834 (delta 1), reused 640 (delta 1), pack-reused 194 (from 1)
# Receiving objects: 100% (834/834), 56.04 MiB | 14.15 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Updating files: 100% (453/453), done.
# Filtering content: 100% (449/449), 160.28 MiB | 9.32 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/Cat_Dog_Detection/.git/hooks/post-checkout': Permission denied

# %%
import os
import numpy as np
import librosa
from skimage.transform import resize
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Input,MaxPool2D,Conv2D
from tensorflow.keras.applications import VGG16
from sklearn.model_selection import train_test_split
import tensorflow as tf
def time_stretch(audio, rate=1.1):
    return librosa.effects.time_stretch(y=audio, rate=rate)

def pitch_shift(audio, sr, n_steps=2):
    return librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=n_steps)

def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    augmented_audio = audio + noise_factor * noise
    return augmented_audio

def normalize(feature):
    return (feature - np.mean(feature)) / np.std(feature)

def load_data(main_directory,files,augment=False,size = 64):
    data = []
    labels = []

    for i,folder in sorted(enumerate(os.listdir(main_directory))):
        folder_path = os.path.join(main_directory, folder)
        if os.path.isdir(folder_path):


            for file in os.listdir(folder_path):
                if file.endswith(".wav") and file in files:
                    file_path = os.path.join(folder_path, file)
                    audio, sr = librosa.load(file_path, sr=None)

                    if augment:
                        augmentation_choice = np.random.random()
                        if augmentation_choice > 0.5:
                            audio = time_stretch(audio, rate=np.random.uniform(0.8, 1.2))
                        #augmentation_choice = np.random.random()
                        # if augmentation_choice > 0.5:
                        #     audio = pitch_shift(audio, sr, n_steps=np.random.randint(-3, 3))
                        augmentation_choice = np.random.random()
                        if augmentation_choice > 0.5:
                            audio = add_noise(audio, noise_factor=np.random.uniform(0.001, 0.01))

                    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
                    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=128)
                    spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr)

                    # mfccs = normalize(mfccs)
                    # mel_spectrogram = normalize(mel_spectrogram)
                    # spectral_contrast = normalize(spectral_contrast)

                    mfccs = resize(np.expand_dims(mfccs, axis=-1), (size, size))
                    mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), (size, size))
                    spectral_contrast = resize(np.expand_dims(spectral_contrast, axis=-1), (size, size))

                    combined_features = np.concatenate([mel_spectrogram,mfccs,spectral_contrast], axis=-1)

                    data.append(combined_features)
                    labels.append(i)

    return np.array(data), np.array(labels)


main_directory = "/content/drive/MyDrive/Cat_Dog_Detection/mydata"
files = os.listdir("/content/drive/MyDrive/Cat_Dog_Detection/mydata/cat")
files.extend(os.listdir("/content/drive/MyDrive/Cat_Dog_Detection/mydata/other"))
train_sample,test_sample= train_test_split(files, test_size=0.2)
train_sample,val_sample= train_test_split(train_sample, test_size=0.25)
print(len(train_sample),len(test_sample),len(val_sample))
x_train,y_train = load_data(main_directory,train_sample,augment=True)
x_val,y_val = load_data(main_directory,val_sample,augment=False)
x_test,y_test = load_data(main_directory,test_sample,augment=False)
y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

input_shape = x_train[0].shape
input_layer = Input(shape=input_shape)
x = Conv2D (filters =16, kernel_size =3, padding ='same', activation='relu')(input_layer)
x = BatchNormalization()(x)
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(x)
x = BatchNormalization()(x)

# x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# # 3rd Conv block

# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# #4th Conv block

# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# # 5th Conv block

# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
# x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# #Fully connected layers

x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(units = 32, activation ='relu')(x)
# x = Dense(units = 256, activation ='relu')(x)
output = Dense(units = 2, activation ='softmax')(x)
model = Model (inputs=input_layer, outputs =output)



model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=250, batch_size=16, validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 269 90 90
# Epoch 1/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.7071 - loss: 3.1622 - val_accuracy: 0.8889 - val_loss: 0.2981
# Epoch 2/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.9345 - loss: 0.6068 - val_accuracy: 0.8222 - val_loss: 0.3548
# Epoch 3/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.9800 - loss: 0.0632 - val_accuracy: 0.7778 - val_loss: 0.4638
# Epoch 4/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.9896 - loss: 0.0172 - val_accuracy: 0.8000 - val_loss: 0.4893
# Epoch 5/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9931 - loss: 0.0155 - val_accuracy: 0.7889 - val_loss: 0.5856
# Epoch 6/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - accuracy: 1.0000 - loss: 8.1575e-04 - val_accuracy: 0.8556 - val_loss: 0.5139
# Epoch 7/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - accuracy: 0.9913 - loss: 0.0067 - val_accuracy: 0.8111 - val_loss: 0.7720
# Epoch 8/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - accuracy: 1.0000 - loss: 5.7717e-04 - val_accuracy: 0.7222 - val_loss: 1.0328
# Epoch 9/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 1.0000 - loss: 2.6424e-04 - val_accuracy: 0.7333 - val_loss: 1.1142
# Epoch 10/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 1.0000 - loss: 5.0673e-04 - val_accuracy: 0.7667 - val_loss: 1.1026
# Epoch 11/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 1.0000 - loss: 9.3819e-05 - val_accuracy: 0.7778 - val_loss: 1.1024
# Epoch 12/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 1.0000 - loss: 1.7467e-04 - val_accuracy: 0.8111 - val_loss: 1.0902
# Epoch 13/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - accuracy: 1.0000 - loss: 1.1234e-04 - val_accuracy: 0.8111 - val_loss: 1.0901
# Epoch 14/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 1.0000 - loss: 1.6037e-04 - val_accuracy: 0.8111 - val_loss: 1.0882
# Epoch 15/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 1.0000 - loss: 4.3065e-05 - val_accuracy: 0.8111 - val_loss: 1.1005
# Epoch 16/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 1.0000 - loss: 4.8101e-05 - val_accuracy: 0.8111 - val_loss: 1.1052
# Epoch 17/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 1.0000 - loss: 9.5372e-05 - val_accuracy: 0.8222 - val_loss: 1.1164
# Epoch 18/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 1.0000 - loss: 5.3754e-05 - val_accuracy: 0.8222 - val_loss: 1.1223
# Epoch 19/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 1.0000 - loss: 1.1868e-04 - val_accuracy: 0.8333 - val_loss: 1.1423
# Epoch 20/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 3.6607e-05 - val_accuracy: 0.8444 - val_loss: 1.1637
# Epoch 21/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 1.0000 - loss: 2.7434e-05 - val_accuracy: 0.8444 - val_loss: 1.1846
# Epoch 22/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 1.0000 - loss: 5.8394e-05 - val_accuracy: 0.8444 - val_loss: 1.2033
# Epoch 23/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - accuracy: 1.0000 - loss: 3.9129e-05 - val_accuracy: 0.8444 - val_loss: 1.2162
# Epoch 24/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 1.0000 - loss: 2.9930e-05 - val_accuracy: 0.8444 - val_loss: 1.2308
# Epoch 25/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 1.0000 - loss: 5.5814e-05 - val_accuracy: 0.8444 - val_loss: 1.2451
# Epoch 26/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 1.0000 - loss: 5.2889e-05 - val_accuracy: 0.8444 - val_loss: 1.2598
# Epoch 27/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 1.0000 - loss: 4.7552e-05 - val_accuracy: 0.8444 - val_loss: 1.2710
# Epoch 28/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 1.0000 - loss: 3.2830e-05 - val_accuracy: 0.8444 - val_loss: 1.2840
# Epoch 29/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 5.3010e-05 - val_accuracy: 0.8556 - val_loss: 1.2971
# Epoch 30/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 1.4857e-05 - val_accuracy: 0.8556 - val_loss: 1.3103
# Epoch 31/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - accuracy: 1.0000 - loss: 2.2668e-05 - val_accuracy: 0.8556 - val_loss: 1.3262
# Epoch 32/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 1.0000 - loss: 1.9777e-05 - val_accuracy: 0.8556 - val_loss: 1.3390
# Epoch 33/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 1.0000 - loss: 6.5381e-05 - val_accuracy: 0.8556 - val_loss: 1.3675
# Epoch 34/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 1.0000 - loss: 2.3453e-05 - val_accuracy: 0.8556 - val_loss: 1.3765
# Epoch 35/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 1.0000 - loss: 3.4887e-05 - val_accuracy: 0.8556 - val_loss: 1.3844
# Epoch 36/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 1.0000 - loss: 6.8576e-06 - val_accuracy: 0.8556 - val_loss: 1.3916
# Epoch 37/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 2.6326e-05 - val_accuracy: 0.8556 - val_loss: 1.3985
# Epoch 38/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 1.0000 - loss: 1.8948e-05 - val_accuracy: 0.8556 - val_loss: 1.4024
# Epoch 39/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 1.0000 - loss: 4.8880e-05 - val_accuracy: 0.8556 - val_loss: 1.4083
# Epoch 40/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8667 - val_loss: 1.0710
# Epoch 41/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9903 - loss: 0.0178 - val_accuracy: 0.8222 - val_loss: 1.1218
# Epoch 42/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.9612 - loss: 0.1945 - val_accuracy: 0.8889 - val_loss: 1.3249
# Epoch 43/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.9615 - loss: 0.2759 - val_accuracy: 0.8556 - val_loss: 3.5297
# Epoch 44/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.9778 - loss: 0.1131 - val_accuracy: 0.8333 - val_loss: 2.8679
# Epoch 45/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9542 - loss: 0.3416 - val_accuracy: 0.8111 - val_loss: 4.8329
# Epoch 46/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9648 - loss: 0.3824 - val_accuracy: 0.8333 - val_loss: 5.1701
# Epoch 47/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9855 - loss: 0.0761 - val_accuracy: 0.8000 - val_loss: 5.0404
# Epoch 48/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.9952 - loss: 0.0495 - val_accuracy: 0.8111 - val_loss: 2.6679
# Epoch 49/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9930 - loss: 0.0930 - val_accuracy: 0.7889 - val_loss: 4.1327
# Epoch 50/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.8111 - val_loss: 4.1618
# Epoch 51/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - accuracy: 1.0000 - loss: 1.0257e-04 - val_accuracy: 0.8000 - val_loss: 3.3437
# Epoch 52/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - accuracy: 1.0000 - loss: 2.2048e-04 - val_accuracy: 0.7889 - val_loss: 3.1162
# Epoch 53/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 1.0000 - loss: 4.8383e-05 - val_accuracy: 0.7889 - val_loss: 3.0166
# Epoch 54/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 1.0000 - loss: 6.7453e-05 - val_accuracy: 0.8000 - val_loss: 2.9483
# Epoch 55/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - accuracy: 1.0000 - loss: 1.0236e-04 - val_accuracy: 0.8000 - val_loss: 2.8750
# Epoch 56/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 0.9964 - loss: 0.0429 - val_accuracy: 0.7889 - val_loss: 3.8001
# Epoch 57/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.9806 - loss: 0.2366 - val_accuracy: 0.8556 - val_loss: 0.6000
# Epoch 58/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - accuracy: 0.9945 - loss: 0.0172 - val_accuracy: 0.8778 - val_loss: 1.4616
# Epoch 59/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.9908 - loss: 0.0101 - val_accuracy: 0.8778 - val_loss: 1.4504
# Epoch 60/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.9977 - loss: 0.0071 - val_accuracy: 0.8778 - val_loss: 1.8341
# Epoch 61/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.9878 - loss: 0.0119 - val_accuracy: 0.8556 - val_loss: 1.8109
# Epoch 62/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 3.8764e-05 - val_accuracy: 0.8444 - val_loss: 1.8182
# Epoch 63/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 1.0000 - loss: 2.2396e-04 - val_accuracy: 0.8556 - val_loss: 1.8028
# Epoch 64/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 1.0000 - loss: 3.1820e-04 - val_accuracy: 0.8778 - val_loss: 1.7874
# Epoch 65/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 1.0000 - loss: 2.4323e-05 - val_accuracy: 0.8667 - val_loss: 1.7903
# Epoch 66/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - accuracy: 1.0000 - loss: 2.4800e-05 - val_accuracy: 0.8667 - val_loss: 1.7988
# Epoch 67/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - accuracy: 1.0000 - loss: 6.8256e-06 - val_accuracy: 0.8556 - val_loss: 1.8074
# Epoch 68/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 1.0000 - loss: 8.2136e-06 - val_accuracy: 0.8556 - val_loss: 1.8158
# Epoch 69/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 1.2357e-05 - val_accuracy: 0.8556 - val_loss: 1.8250
# Epoch 70/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 1.9773e-05 - val_accuracy: 0.8556 - val_loss: 1.8334
# Epoch 71/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 1.0000 - loss: 1.4172e-05 - val_accuracy: 0.8556 - val_loss: 1.8417
# Epoch 72/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - accuracy: 1.0000 - loss: 9.7719e-05 - val_accuracy: 0.8556 - val_loss: 1.8392
# Epoch 73/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 1.0000 - loss: 3.3223e-05 - val_accuracy: 0.8556 - val_loss: 1.8529
# Epoch 74/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 1.0000 - loss: 2.5805e-05 - val_accuracy: 0.8556 - val_loss: 1.8648
# Epoch 75/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 1.0000 - loss: 6.4192e-06 - val_accuracy: 0.8556 - val_loss: 1.8687
# Epoch 76/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 1.0000 - loss: 8.6171e-06 - val_accuracy: 0.8556 - val_loss: 1.8739
# Epoch 77/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - accuracy: 1.0000 - loss: 3.7152e-05 - val_accuracy: 0.8556 - val_loss: 1.8824
# Epoch 78/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 190ms/step - accuracy: 1.0000 - loss: 3.8252e-06 - val_accuracy: 0.8556 - val_loss: 1.8886
# Epoch 79/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 252ms/step - accuracy: 1.0000 - loss: 8.8259e-06 - val_accuracy: 0.8556 - val_loss: 1.8890
# Epoch 80/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - accuracy: 1.0000 - loss: 1.4665e-05 - val_accuracy: 0.8556 - val_loss: 1.8960
# Epoch 81/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 3.5505e-06 - val_accuracy: 0.8556 - val_loss: 1.9007
# Epoch 82/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 5.3226e-06 - val_accuracy: 0.8556 - val_loss: 1.9008
# Epoch 83/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 1.0000 - loss: 1.7009e-06 - val_accuracy: 0.8556 - val_loss: 1.9008
# Epoch 84/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 7.3663e-06 - val_accuracy: 0.8556 - val_loss: 1.9040
# Epoch 85/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 1.0000 - loss: 2.3249e-06 - val_accuracy: 0.8556 - val_loss: 1.9044
# Epoch 86/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - accuracy: 1.0000 - loss: 5.3521e-06 - val_accuracy: 0.8556 - val_loss: 1.9051
# Epoch 87/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 1.0000 - loss: 1.1476e-05 - val_accuracy: 0.8556 - val_loss: 1.9071
# Epoch 88/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 1.9932e-06 - val_accuracy: 0.8556 - val_loss: 1.9100
# Epoch 89/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step - accuracy: 1.0000 - loss: 1.4933e-05 - val_accuracy: 0.8556 - val_loss: 1.9107
# Epoch 90/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 1.0000 - loss: 2.1462e-04 - val_accuracy: 0.8333 - val_loss: 2.0103
# Epoch 91/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 2.5593e-06 - val_accuracy: 0.8222 - val_loss: 2.1115
# Epoch 92/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 1.0000 - loss: 1.2743e-05 - val_accuracy: 0.8222 - val_loss: 2.1245
# Epoch 93/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 1.0000 - loss: 3.0279e-06 - val_accuracy: 0.8222 - val_loss: 2.1237
# Epoch 94/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 6.7862e-06 - val_accuracy: 0.8222 - val_loss: 2.1224
# Epoch 95/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 2.2669e-05 - val_accuracy: 0.8222 - val_loss: 2.1050
# Epoch 96/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 1.0000 - loss: 5.3578e-06 - val_accuracy: 0.8222 - val_loss: 2.1020
# Epoch 97/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - accuracy: 1.0000 - loss: 6.7218e-06 - val_accuracy: 0.8222 - val_loss: 2.1014
# Epoch 98/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 4.3613e-06 - val_accuracy: 0.8222 - val_loss: 2.1001
# Epoch 99/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 4.5781e-06 - val_accuracy: 0.8222 - val_loss: 2.1015
# Epoch 100/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 1.0000 - loss: 9.0700e-05 - val_accuracy: 0.8333 - val_loss: 2.0395
# Epoch 101/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 1.0000 - loss: 1.2287e-05 - val_accuracy: 0.8778 - val_loss: 1.6513
# Epoch 102/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 189ms/step - accuracy: 1.0000 - loss: 3.2049e-05 - val_accuracy: 0.8778 - val_loss: 1.6315
# Epoch 103/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - accuracy: 1.0000 - loss: 2.6600e-05 - val_accuracy: 0.8778 - val_loss: 1.6492
# Epoch 104/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 2.6777e-05 - val_accuracy: 0.8667 - val_loss: 1.6669
# Epoch 105/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 1.0000 - loss: 7.6179e-06 - val_accuracy: 0.8667 - val_loss: 1.6844
# Epoch 106/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 1.0000 - loss: 4.0519e-06 - val_accuracy: 0.8667 - val_loss: 1.6973
# Epoch 107/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - accuracy: 1.0000 - loss: 5.4235e-06 - val_accuracy: 0.8667 - val_loss: 1.7074
# Epoch 108/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 1.0000 - loss: 5.2015e-06 - val_accuracy: 0.8667 - val_loss: 1.7192
# Epoch 109/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - accuracy: 1.0000 - loss: 3.8225e-05 - val_accuracy: 0.8667 - val_loss: 1.7341
# Epoch 110/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 1.0000 - loss: 5.3736e-06 - val_accuracy: 0.8667 - val_loss: 1.7475
# Epoch 111/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 4.2560e-05 - val_accuracy: 0.8667 - val_loss: 1.7631
# Epoch 112/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 1.0000 - loss: 3.1834e-05 - val_accuracy: 0.8667 - val_loss: 1.7751
# Epoch 113/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 1.0000 - loss: 1.0424e-05 - val_accuracy: 0.8667 - val_loss: 1.7850
# Epoch 114/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 1.0000 - loss: 2.1090e-04 - val_accuracy: 0.8556 - val_loss: 1.8602
# Epoch 115/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 1.0000 - loss: 1.6445e-06 - val_accuracy: 0.8556 - val_loss: 1.8816
# Epoch 116/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - accuracy: 1.0000 - loss: 5.8553e-06 - val_accuracy: 0.8556 - val_loss: 1.8873
# Epoch 117/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 1.0000 - loss: 1.4942e-05 - val_accuracy: 0.8556 - val_loss: 1.8905
# Epoch 118/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 1.0000 - loss: 9.6355e-07 - val_accuracy: 0.8556 - val_loss: 1.8934
# Epoch 119/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 3.0751e-06 - val_accuracy: 0.8556 - val_loss: 1.8928
# Epoch 120/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - accuracy: 1.0000 - loss: 4.6172e-06 - val_accuracy: 0.8556 - val_loss: 1.8943
# Epoch 121/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 1.0000 - loss: 6.4071e-06 - val_accuracy: 0.8556 - val_loss: 1.8965
# Epoch 122/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 1.0000 - loss: 4.3810e-06 - val_accuracy: 0.8556 - val_loss: 1.8989
# Epoch 123/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - accuracy: 1.0000 - loss: 1.9618e-06 - val_accuracy: 0.8556 - val_loss: 1.8994
# Epoch 124/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 2.2732e-05 - val_accuracy: 0.8556 - val_loss: 1.9041
# Epoch 125/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 1.0000 - loss: 2.2953e-06 - val_accuracy: 0.8556 - val_loss: 1.9062
# Epoch 126/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 1.0000 - loss: 1.5812e-06 - val_accuracy: 0.8556 - val_loss: 1.9059
# Epoch 127/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 1.0000 - loss: 2.8870e-06 - val_accuracy: 0.8556 - val_loss: 1.9076
# Epoch 128/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 4.7174e-06 - val_accuracy: 0.8556 - val_loss: 1.9120
# Epoch 129/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - accuracy: 1.0000 - loss: 2.5460e-06 - val_accuracy: 0.8556 - val_loss: 1.9108
# Epoch 130/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 1.0000 - loss: 6.6032e-06 - val_accuracy: 0.8556 - val_loss: 1.9137
# Epoch 131/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 1.5478e-06 - val_accuracy: 0.8556 - val_loss: 1.9138
# Epoch 132/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 1.0000 - loss: 6.2595e-06 - val_accuracy: 0.8556 - val_loss: 1.9152
# Epoch 133/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 331ms/step - accuracy: 1.0000 - loss: 3.4380e-07 - val_accuracy: 0.8556 - val_loss: 1.9157
# Epoch 134/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step - accuracy: 1.0000 - loss: 3.6622e-06 - val_accuracy: 0.8556 - val_loss: 1.9159
# Epoch 135/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - accuracy: 1.0000 - loss: 7.0209e-07 - val_accuracy: 0.8556 - val_loss: 1.9161
# Epoch 136/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 1.0000 - loss: 6.5038e-06 - val_accuracy: 0.8556 - val_loss: 1.9193
# Epoch 137/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 1.0000 - loss: 2.1563e-06 - val_accuracy: 0.8556 - val_loss: 1.9224
# Epoch 138/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - accuracy: 1.0000 - loss: 2.6000e-06 - val_accuracy: 0.8444 - val_loss: 1.9225
# Epoch 139/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - accuracy: 1.0000 - loss: 4.3824e-06 - val_accuracy: 0.8444 - val_loss: 1.9242
# Epoch 140/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 1.0000 - loss: 2.0748e-05 - val_accuracy: 0.8444 - val_loss: 1.9300
# Epoch 141/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 1.0000 - loss: 1.2164e-06 - val_accuracy: 0.8444 - val_loss: 1.9312
# Epoch 142/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 189ms/step - accuracy: 1.0000 - loss: 1.2759e-05 - val_accuracy: 0.8444 - val_loss: 1.9272
# Epoch 143/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - accuracy: 1.0000 - loss: 9.2516e-06 - val_accuracy: 0.8444 - val_loss: 1.9214
# Epoch 144/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 1.0000 - loss: 8.3044e-07 - val_accuracy: 0.8444 - val_loss: 1.9198
# Epoch 145/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 1.0000 - loss: 7.2549e-07 - val_accuracy: 0.8444 - val_loss: 1.9212
# Epoch 146/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 7.9177e-07 - val_accuracy: 0.8444 - val_loss: 1.9215
# Epoch 147/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 1.0000 - loss: 3.4164e-06 - val_accuracy: 0.8444 - val_loss: 1.9217
# Epoch 148/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 1.0000 - loss: 2.4149e-06 - val_accuracy: 0.8444 - val_loss: 1.9208
# Epoch 149/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 1.7853e-06 - val_accuracy: 0.8444 - val_loss: 1.9215
# Epoch 150/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 1.7440e-06 - val_accuracy: 0.8444 - val_loss: 1.9202
# Epoch 151/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - accuracy: 1.0000 - loss: 4.5374e-07 - val_accuracy: 0.8444 - val_loss: 1.9205
# Epoch 152/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 1.0000 - loss: 4.8091e-06 - val_accuracy: 0.8444 - val_loss: 1.9218
# Epoch 153/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 1.0000 - loss: 5.2121e-06 - val_accuracy: 0.8444 - val_loss: 1.9267
# Epoch 154/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 1.0000 - loss: 1.1958e-06 - val_accuracy: 0.8444 - val_loss: 1.9273
# Epoch 155/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 1.0000 - loss: 6.3122e-07 - val_accuracy: 0.8444 - val_loss: 1.9263
# Epoch 156/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 1.0000 - loss: 4.7517e-06 - val_accuracy: 0.8444 - val_loss: 1.9310
# Epoch 157/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - accuracy: 1.0000 - loss: 1.3506e-06 - val_accuracy: 0.8444 - val_loss: 1.9353
# Epoch 158/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 1.0000 - loss: 4.0107e-07 - val_accuracy: 0.8444 - val_loss: 1.9359
# Epoch 159/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 1.0000 - loss: 4.4946e-06 - val_accuracy: 0.8444 - val_loss: 1.9362
# Epoch 160/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - accuracy: 1.0000 - loss: 3.8658e-06 - val_accuracy: 0.8444 - val_loss: 1.9385
# Epoch 161/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - accuracy: 1.0000 - loss: 2.7238e-06 - val_accuracy: 0.8444 - val_loss: 1.9414
# Epoch 162/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 2.4234e-06 - val_accuracy: 0.8444 - val_loss: 1.9429
# Epoch 163/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 2.5040e-06 - val_accuracy: 0.8444 - val_loss: 1.9429
# Epoch 164/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 1.0000 - loss: 1.3593e-06 - val_accuracy: 0.8444 - val_loss: 1.9435
# Epoch 165/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 1.0000 - loss: 1.8464e-06 - val_accuracy: 0.8444 - val_loss: 1.9447
# Epoch 166/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 2.7458e-06 - val_accuracy: 0.8444 - val_loss: 1.9445
# Epoch 167/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 1.0000 - loss: 4.4017e-07 - val_accuracy: 0.8444 - val_loss: 1.9414
# Epoch 168/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 1.0000 - loss: 1.6277e-05 - val_accuracy: 0.8444 - val_loss: 1.9451
# Epoch 169/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 1.0000 - loss: 6.8221e-07 - val_accuracy: 0.8444 - val_loss: 1.9501
# Epoch 170/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 1.0000 - loss: 2.1519e-06 - val_accuracy: 0.8444 - val_loss: 1.9522
# Epoch 171/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 1.0000 - loss: 7.4359e-07 - val_accuracy: 0.8444 - val_loss: 1.9518
# Epoch 172/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 8.9355e-07 - val_accuracy: 0.8444 - val_loss: 1.9519
# Epoch 173/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 1.0000 - loss: 2.1928e-06 - val_accuracy: 0.8444 - val_loss: 1.9499
# Epoch 174/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - accuracy: 1.0000 - loss: 2.8346e-06 - val_accuracy: 0.8444 - val_loss: 1.9507
# Epoch 175/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 1.0000 - loss: 8.7022e-07 - val_accuracy: 0.8444 - val_loss: 1.9507
# Epoch 176/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 1.0000 - loss: 1.6327e-05 - val_accuracy: 0.8444 - val_loss: 1.9623
# Epoch 177/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 1.0000 - loss: 3.9302e-06 - val_accuracy: 0.8444 - val_loss: 1.9692
# Epoch 178/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 7.1610e-07 - val_accuracy: 0.8444 - val_loss: 1.9722
# Epoch 179/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 1.3703e-06 - val_accuracy: 0.8444 - val_loss: 1.9713
# Epoch 180/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 1.2511e-06 - val_accuracy: 0.8444 - val_loss: 1.9726
# Epoch 181/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 1.0145e-06 - val_accuracy: 0.8444 - val_loss: 1.9734
# Epoch 182/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 1.1886e-06 - val_accuracy: 0.8444 - val_loss: 1.9758
# Epoch 183/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 1.0000 - loss: 2.3740e-06 - val_accuracy: 0.8444 - val_loss: 1.9780
# Epoch 184/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 1.0000 - loss: 9.1112e-07 - val_accuracy: 0.8444 - val_loss: 1.9800
# Epoch 185/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - accuracy: 1.0000 - loss: 2.0195e-06 - val_accuracy: 0.8444 - val_loss: 1.9836
# Epoch 186/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 4.8445e-07 - val_accuracy: 0.8444 - val_loss: 1.9852
# Epoch 187/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 1.0000 - loss: 1.2714e-06 - val_accuracy: 0.8444 - val_loss: 1.9874
# Epoch 188/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 1.0000 - loss: 2.0210e-06 - val_accuracy: 0.8444 - val_loss: 1.9867
# Epoch 189/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 8.2610e-07 - val_accuracy: 0.8444 - val_loss: 1.9850
# Epoch 190/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 1.0000 - loss: 8.9490e-07 - val_accuracy: 0.8444 - val_loss: 1.9846
# Epoch 191/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 1.0000 - loss: 6.6113e-07 - val_accuracy: 0.8444 - val_loss: 1.9832
# Epoch 192/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 1.0000 - loss: 4.0088e-07 - val_accuracy: 0.8444 - val_loss: 1.9830
# Epoch 193/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - accuracy: 1.0000 - loss: 1.7674e-06 - val_accuracy: 0.8444 - val_loss: 1.9820
# Epoch 194/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 1.0000 - loss: 8.6880e-07 - val_accuracy: 0.8444 - val_loss: 1.9836
# Epoch 195/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 1.0000 - loss: 9.6348e-06 - val_accuracy: 0.8444 - val_loss: 1.9870
# Epoch 196/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 1.0000 - loss: 1.1418e-06 - val_accuracy: 0.8444 - val_loss: 1.9864
# Epoch 197/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 1.0000 - loss: 9.6254e-07 - val_accuracy: 0.8444 - val_loss: 1.9889
# Epoch 198/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 1.0000 - loss: 8.8711e-07 - val_accuracy: 0.8444 - val_loss: 1.9930
# Epoch 199/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 1.0000 - loss: 7.8818e-07 - val_accuracy: 0.8444 - val_loss: 1.9939
# Epoch 200/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 1.0000 - loss: 5.0643e-07 - val_accuracy: 0.8444 - val_loss: 1.9944
# Epoch 201/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 1.0000 - loss: 4.7446e-07 - val_accuracy: 0.8444 - val_loss: 1.9929
# Epoch 202/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 1.4415e-06 - val_accuracy: 0.8444 - val_loss: 1.9912
# Epoch 203/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 5.8418e-07 - val_accuracy: 0.8444 - val_loss: 1.9922
# Epoch 204/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 3.3474e-06 - val_accuracy: 0.8444 - val_loss: 1.9919
# Epoch 205/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - accuracy: 1.0000 - loss: 4.7561e-07 - val_accuracy: 0.8444 - val_loss: 1.9938
# Epoch 206/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 1.0000 - loss: 1.8832e-06 - val_accuracy: 0.8444 - val_loss: 1.9940
# Epoch 207/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 2.8659e-07 - val_accuracy: 0.8444 - val_loss: 1.9963
# Epoch 208/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - accuracy: 1.0000 - loss: 4.2827e-06 - val_accuracy: 0.8444 - val_loss: 1.9971
# Epoch 209/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 3.1364e-06 - val_accuracy: 0.8444 - val_loss: 1.9946
# Epoch 210/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 1.0000 - loss: 1.3016e-06 - val_accuracy: 0.8444 - val_loss: 1.9958
# Epoch 211/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - accuracy: 1.0000 - loss: 3.9570e-07 - val_accuracy: 0.8444 - val_loss: 1.9968
# Epoch 212/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 1.0000 - loss: 1.0163e-06 - val_accuracy: 0.8444 - val_loss: 1.9973
# Epoch 213/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 1.8736e-06 - val_accuracy: 0.8444 - val_loss: 1.9985
# Epoch 214/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 1.0000 - loss: 2.3876e-07 - val_accuracy: 0.8444 - val_loss: 1.9997
# Epoch 215/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 1.0000 - loss: 7.6381e-07 - val_accuracy: 0.8444 - val_loss: 2.0016
# Epoch 216/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 4.2030e-07 - val_accuracy: 0.8444 - val_loss: 2.0008
# Epoch 217/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 1.0000 - loss: 1.3034e-06 - val_accuracy: 0.8444 - val_loss: 2.0003
# Epoch 218/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 1.0000 - loss: 9.3457e-07 - val_accuracy: 0.8444 - val_loss: 2.0002
# Epoch 219/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 1.0000 - loss: 4.3851e-07 - val_accuracy: 0.8444 - val_loss: 2.0005
# Epoch 220/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 1.8080e-06 - val_accuracy: 0.8444 - val_loss: 2.0004
# Epoch 221/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 1.0000 - loss: 8.0880e-07 - val_accuracy: 0.8444 - val_loss: 2.0017
# Epoch 222/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - accuracy: 1.0000 - loss: 5.9337e-07 - val_accuracy: 0.8444 - val_loss: 2.0021
# Epoch 223/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 1.1752e-06 - val_accuracy: 0.8444 - val_loss: 2.0055
# Epoch 224/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 1.0000 - loss: 1.0184e-06 - val_accuracy: 0.8444 - val_loss: 2.0069
# Epoch 225/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 212ms/step - accuracy: 1.0000 - loss: 2.3512e-06 - val_accuracy: 0.8444 - val_loss: 2.0091
# Epoch 226/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 1.0000 - loss: 3.0793e-06 - val_accuracy: 0.8444 - val_loss: 2.0123
# Epoch 227/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 1.0000 - loss: 4.6406e-07 - val_accuracy: 0.8444 - val_loss: 2.0112
# Epoch 228/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 1.0000 - loss: 1.4578e-06 - val_accuracy: 0.8444 - val_loss: 2.0139
# Epoch 229/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 1.0000 - loss: 1.3456e-06 - val_accuracy: 0.8444 - val_loss: 2.0163
# Epoch 230/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - accuracy: 1.0000 - loss: 5.0718e-07 - val_accuracy: 0.8444 - val_loss: 2.0174
# Epoch 231/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 1.0000 - loss: 6.3029e-07 - val_accuracy: 0.8444 - val_loss: 2.0205
# Epoch 232/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 1.0000 - loss: 5.6604e-06 - val_accuracy: 0.8444 - val_loss: 2.0114
# Epoch 233/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 1.0000 - loss: 8.0095e-06 - val_accuracy: 0.8444 - val_loss: 1.9963
# Epoch 234/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 1.0000 - loss: 9.1025e-07 - val_accuracy: 0.8444 - val_loss: 1.9791
# Epoch 235/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 1.0000 - loss: 7.7053e-07 - val_accuracy: 0.8444 - val_loss: 1.9777
# Epoch 236/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 1.0000 - loss: 8.4875e-07 - val_accuracy: 0.8444 - val_loss: 1.9785
# Epoch 237/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 1.0000 - loss: 2.8855e-06 - val_accuracy: 0.8444 - val_loss: 1.9769
# Epoch 238/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 1.0000 - loss: 2.1521e-06 - val_accuracy: 0.8444 - val_loss: 1.9750
# Epoch 239/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 1.0000 - loss: 1.4135e-06 - val_accuracy: 0.8444 - val_loss: 1.9770
# Epoch 240/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 1.0000 - loss: 6.3217e-07 - val_accuracy: 0.8444 - val_loss: 1.9749
# Epoch 241/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - accuracy: 1.0000 - loss: 1.0992e-06 - val_accuracy: 0.8444 - val_loss: 1.9764
# Epoch 242/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - accuracy: 1.0000 - loss: 1.8302e-06 - val_accuracy: 0.8444 - val_loss: 1.9766
# Epoch 243/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 1.0000 - loss: 1.6653e-06 - val_accuracy: 0.8444 - val_loss: 1.9797
# Epoch 244/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 1.0000 - loss: 1.1584e-06 - val_accuracy: 0.8444 - val_loss: 1.9823
# Epoch 245/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - accuracy: 1.0000 - loss: 3.8824e-07 - val_accuracy: 0.8444 - val_loss: 1.9830
# Epoch 246/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 1.0000 - loss: 6.9563e-07 - val_accuracy: 0.8444 - val_loss: 1.9826
# Epoch 247/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 4.9004e-07 - val_accuracy: 0.8444 - val_loss: 1.9848
# Epoch 248/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 1.0000 - loss: 2.2224e-05 - val_accuracy: 0.8444 - val_loss: 1.9469
# Epoch 249/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 1.0000 - loss: 1.4872e-07 - val_accuracy: 0.8556 - val_loss: 1.8912
# Epoch 250/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 1.0000 - loss: 8.5837e-07 - val_accuracy: 0.8556 - val_loss: 1.8810
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8201 - loss: 2.6373
# Test accuracy: 0.8667
